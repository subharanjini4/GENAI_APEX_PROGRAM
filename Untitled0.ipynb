# %% [markdown]
# <a href="https://colab.research.google.com/github/subharanjini4/GENAI_APEX_PROGRAM/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U google-generativeai

# %%
import google.generativeai as genai

# %%
genai.configure(api_key="AIzaSyB9x84dD4jwXsu_zvaRrgzAGW4_ux-dBJk")

# %%
vision_model=genai.GenerativeModel("gemini-1.5-flash")

# %%
vision_model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-1.5-flash',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %%
from PIL import Image

# %%
img=Image.open("/teedy.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=236x314>

# %%
vision_model.generate_content(["explain yhos image",img]).text
# Out:
# "That's a digital image of a pink teddy bear sitting under a pink umbrella in the rain.\n\nHere's a breakdown of the image's elements and likely intended feeling:\n\n* **The Teddy Bear:** A plush, pink teddy bear is the central focus.  Its design is cute and cuddly, typical of a children's toy.  The pink color reinforces the overall sweet and gentle aesthetic.\n\n* **The Umbrella:** A matching pink umbrella is held above the bear, shielding it from the rain. This acts as a protective element, highlighting the idea of care and shelter.\n\n* **The Rain:**  The background shows a stormy sky with rain falling.  This creates a contrast with the cozy and protected scene of the bear.  The rain suggests a slightly melancholic or wistful mood, but the umbrella keeps it from being overtly sad.\n\n* **The Setting:** The bear sits on a pink platform, further emphasizing the consistent color scheme and overall softness.  The background is blurred, drawing attention to the bear.\n\n**Overall Impre
# ...

# %%
vision_model1=genai.GenerativeModel("gemini-1.5-flash")

# %%
vision_model1
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-1.5-flash',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %%
from PIL import Image

# %%
img=Image.open("/kiot.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=480x360>

# %%
print(vision_model1.generate_content(["explain this image",img]).text)
# Out:
# This is an advertisement for the Knowledge Institute of Technology (KIT).
#
# The image shows a picture of the KIT campus, a modern-looking building complex.  Overlayed on the image is text giving information about the institute:
#
# * **Name:** Knowledge Institute of Technology
# * **Accreditations:** Approved by AICTE, New Delhi and affiliated with Anna University, Chennai.  (AICTE is the All India Council for Technical Education)
# * **Contact Information:** A phone number is prominently displayed: 0427 - 2441700
# * **Live Event:** The words "Live" and a phone icon suggest a live event or broadcast is about to start.
# * **Tamil Text:** There's Tamil text, likely advertising a special live event or announcement.  The English translation is roughly: "Special Live Program, In a few moments..."
#
# In short, the image is a promotional piece for the Knowledge Institute of Technology, announcing an upcoming live event and providing contact details.

# %%
vision_model2=genai.GenerativeModel("gemini-1.5-flash")

# %%
vision_model2
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-1.5-flash',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %%
from PIL import Image

# %%
img=Image.open("/content/food.jpeg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=262x192>

# %%
print(vision_model2.generate_content(["explain this image",img]).text)
# Out:
# That's a photo of a South Indian Thali.
#
# A Thali is a type of meal served on a large platter (often a metal one like in the image).  This particular Thali showcases a variety of South Indian dishes, typically served together for a complete and balanced meal.
#
# The image shows:
#
# * **Rice:** A mound of steamed rice sits in the center, the base of the meal.
# * **Various Curries/Side Dishes:**  Several small bowls surround the rice, containing different curries (likely vegetable, lentil, and maybe fish or meat), chutneys (yogurt-based or spicy), and possibly sambar (a lentil-based vegetable stew).
# * **Appam/Roti:** A flatbread, likely a roti or appam, is placed next to the rice. It's used to scoop up the various curries.
# * **Papadum/Other Snacks:** There's a possibility of a papadum or another type of crispy snack present.
# ...
